# %%
10+273
# Out:
# 283

# %%
40-23
# Out:
# 17

# %%
45/4
# Out:
# 11.25

# %%
3*6
# Out:
# 18

# %%
23/7
# Out:
# 3.2857142857142856

# %%
print("hello world")
# Out:
# hello world

# %%
print ('Hello World')
# Out:
# Hello World

# %%
x=20
y=30
z=29
print (20+30+29)
# Out:
# 79

# %%
x=20
y=30
z=29
print ("The Addition of all numbers is", 20+30+29)
# Out:
# The Addition of all numbers is 79

# %%
x,y,z = 22,34,78
print (x+y+z)
print (x+y-z)
print (x/y+z)
print (x*y*z)
# Out:
# 134
# -22
# 78.6470588235294
# 58344

# %%
#Addition 
a=100
b=78
print (a+b)
# Out:
# 178

# %%
#Subtraction
print (a-b)
# Out:
# 22

# %%
#Multiplication
print (a*b)
# Out:
# 7800

# %%
#Division
print (a/b)
# Out:
# 1.2820512820512822

# %%
#Modulus
a=30
b=4
print (a%b)
# Out:
# 2

# %%
#Exponent
a=4
b=2
print (a**b)
# Out:
# 16

# %%
#Relational Operators
#Equal to "=="
a=
