# %%
10+273
# Out:
# 283

# %%
40-23
# Out:
# 17

# %%
45/4
# Out:
# 11.25

# %%
3*6
# Out:
# 18

# %%
23/7
# Out:
# 3.2857142857142856

# %%
print("hello world")
# Out:
# hello world

# %%
print ('Hello World')
# Out:
# Hello World
