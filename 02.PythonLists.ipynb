# %%
A list is a data structure in Python that is a mutable, or chnagable, ordered sequesnce of elements.

# %%
my_list = [44,24,10,40.5,'Yes','No',True]
print (my_list[4])
# Out:
# Yes

# %%
len(my_list) #leng
# Out:
# 7

# %%
my_list = ['one','two','three',455,244,455,'four']
newList = [10,20,30,40,50]

# %%
List Indexing

# %%
my_list[1:3]
# Out:
# [24, 10]

# %%
10+2- #botg are integers

# %%
pop, append, concatinate

# %%
newstring = ['I','take','the','boring','classes','on','weekends']

# %%
output: "I take intresting classes on the weekends and weekdays"

# %%
newstring = ['I','take','the','boring','classes','on','weekends']
newstring.append('and')

# %%
newstring[3] = "intresting"
newstring.pop(2)
newstring.append('and weekdays')

# %%
print(newstring)
# Out:
# ['I', 'take', 'intresting', 'classes', 'on', 'weekends', 'and weekdays']

# %%
print(" ".join(newstring))
# Out:
# I take intresting classes on weekends and weekdays

# %%
newstring.pop(4)
# Out:
# 'classes'

# %%
newstring.pop(3)
# Out:
# 'boring'

# %%
newstring
# Out:
# ['I', 'take', 'the', 'on', 'weekends', 'and', 'weekdays']

# %%
newstring.pop(2)
# Out:
# 'the'

# %%
newstring.index(2,"intresting")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 newstring.index(2,"intresting")
#
# TypeError: slice indices must be integers or have an __index__ method

# %%
list1= ['asdf','asdf3ff',1,3,4,24,23,3] 
list2= [272,1,234,82992,29323,'nasfdi','kabfd']
newList = list1 + list2       #Concatinating the lists

# %%
newList
# Out:
# ['asdf',
#  'asdf3ff',
#  1,
#  3,
#  4,
#  24,
#  23,
#  3,
#  272,
#  1,
#  234,
#  82992,
#  29323,
#  'nasfdi',
#  'kabfd']

# %%
list1[1] = 'Besant' #Replacing the specific index value in the list

# %%
print(list1)
# Out:
# ['asdf', 'Besant', 1, 3, 4, 24, 23, 3]

# %%
list1[0] = 'Technoligies'

# %%
print(list1)
# Out:
# ['Technoligies', 'Besant', 1, 3, 4, 24, 23, 3]

# %%
newList = [10,20,30,40,50]

# %%
newList
# Out:
# [10, 20, 30, 40, 50]

# %%
newList.append("Hello")    #append means adding the new element in the list at last

# %%
newList
# Out:
# [10, 20, 30, 40, 50, 'Hello']

# %%
newList.pop(2)  #pop means removing the specific element in the index value of the list
# Out:
# 30

# %%
newList
# Out:
# [10, 20, 40, 50, 'Hello']

# %%
list1 = [1,2,3,4,5]
list2 = [20,30,40,50]

# %%
list1.append(list2)  #here append means concatinating the 2 lists

# %%
list1
# Out:
# [1, 2, 3, 4, 5, [20, 30, 40, 50]]

# %%
print(list1[5][2])   #Here printing the specific value in the index value of 5 in the concainated list 5, 2 represnts the elemnts in the list
# Out:
# 40

# %%
#Test
newstring = ['I','take','the','boring','classes','on','weekends']
#output: "I take intresting classes on the weekends and weekdays"   Excepted ouptput

# %%
newstring[2] = 'intresting'

# %%
newstring
# Out:
# ['I', 'take', 'intresting', 'boring', 'classes', 'on', 'weekends']

# %%
newstring.pop(3)
# Out:
# 'boring'

# %%
newstring
# Out:
# ['I', 'take', 'intresting', 'classes', 'on', 'weekends']

# %%
newstring.append('and weekdays')

# %%
newstring
# Out:
# ['I', 'take', 'intresting', 'classes', 'on', 'weekends', 'and weekdays']

# %%
resut = newstring[0]+ ' ' + newstring[1]+ ' ' + newstring[2]+ ' ' + newstring[3]+ ' ' + newstring[4]+ ' ' + newstring[5]+ ' ' + newstring[6]

# %%
newstring
# Out:
# ['I', 'take', 'intresting', 'classes', 'on', 'weekends', 'and weekdays']

# %%
"".join([newstring])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 "".join([newstring])
#
# TypeError: sequence item 0: expected str instance, list found

# %%
newList = ['A','f','k','a','d','z','Z','Y']
numList = [9,2,6,1,4,6,5]
numList.sort()

# %%
numList
# Out:
# [1, 2, 4, 5, 6, 6, 9]

# %%
newList.sort()

# %%
newList
# Out:
# ['A', 'Y', 'Z', 'a', 'd', 'f', 'k', 'z']

# %%
numList.count(6)
# Out:
# 2

# %%
newList.index('a')
# Out:
# 3

# %%
help(newList)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
dir(newList)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
t.count(9)
# Out:
# 0

# %%
list_cities = ["Bangalore", "Chennai", "Hyderabad", "Vizag"]

# %%
list_cities.append("Mumbai")

# %%
list_cities
# Out:
# ['Bangalore', 'Chennai', 'Hyderabad', 'Vizag', 'Mumbai']

# %%
list_cities.pop(2)
# Out:
# 'Hyderabad'

# %%
list_cities
# Out:
# ['Bangalore', 'Chennai', 'Vizag', 'Mumbai']

# %%
servers = ["web","app","db"]

# %%
len(servers)
# Out:
# 3

# %%
servers[2]
# Out:
# 'db'

# %%
servers.append("messaging")

# %%
servers
# Out:
# ['web', 'app', 'db', 'messaging']

# %%
servers.pop(1)
# Out:
# 'app'

# %%
servers
# Out:
# ['web', 'db', 'messaging']

# %%
servers.extend(["web1","web2","backend","nginx"])

# %%
servers
# Out:
# ['web', 'db', 'messaging', 'web1', 'web2', 'backend', 'nginx']

# %%
servers[1:3]
# Out:
# ['db', 'messaging']

# %%
servers
# Out:
# ['web', 'db', 'messaging', 'web1', 'web2', 'backend', 'nginx']

# %%
del servers[1:3]

# %%
servers
# Out:
# ['web', 'web1', 'web2', 'backend', 'nginx']

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
servers.sort()

# %%
servers
# Out:
# ['backend', 'nginx', 'web', 'web1', 'web2']

# %%
servers.remove('web')

# %%
servers
# Out:
# ['backend', 'nginx', 'web1', 'web2']

# %%
count(servers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 count(servers)
#
# NameError: name 'count' is not defined

# %%
data = [
    ["Fazal", 25, "DevOps"],
    ["Ahmed", 28, "Developer"],
    ["Rafi", 24, "Tester"]
]

# %%
print (data[1][2])
# Out:
# Developer

# %%
new_list = ["hello", 23, 123.37, -24.23, True, False]

# %%
type(new_list)
# Out:
# list

# %%
len(new_list)
# Out:
# 6

# %%
new_list.append("new_thing")

# %%
new_list
# Out:
# ['hello', 23, 123.37, -24.23, True, False, 'new_thing']

# %%
print(new_list)
# Out:
# ['hello', 23, 123.37, -24.23, True, False, 'new_thing']

# %%
new_list.pop(3)
# Out:
# -24.23

# %%
new_list
# Out:
# ['hello', 23, 123.37, True, False, 'new_thing']

# %%
new_list.index(True)
# Out:
# 3

# %%
len(new_list)
# Out:
# 6

# %%
new_list.pop()
# Out:
# False

# %%
new_list
# Out:
# ['hello', 23, 123.37, True]

# %%
new_list[2] = 24

# %%
new_list
# Out:
# ['hello', 23, 24, True]
