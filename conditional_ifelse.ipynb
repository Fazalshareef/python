# %%
A Control Flow is used when we often only want certain code to execute when a particular condition has been met.
    1. if
    2. elfi
    3. elso

Control flow syntax in python

1. Uses colons
2. Uses white spaces (indentation) - means giving space through tab button.

# %%
switch = True

if switch:
    print ('Condition successful')
else:
    print ("Condition Unsuccessful")
# Out:
# Condition sucessfull

# %%
switch = False
if switch:
    print ('Condition successful')
else:
    print('Condition unsucessfull')
# Out:
# Condition unsucessfull

# %%
x = 200
print ("Hi")
if x>100:
    print("Hello")
elif x<300:
    print("Hello again")
    print("x is less than 500")
elif x == 500:
    print("x is equal to 500")
else: 
    print("x is greater than 500")
print("Bye")
# Out:
# Hi
# Hello
# Bye

# %%
x = 1500
print('Hello')
if x>5000:
    print ('X is less than 15000')
elif x<=1500:
    print ('x is equal to 1500')
else:
    print ('x is greater than 1500')
print ('I am not confused')
print ('Bye')
# Out:
# Hello
# x is equal to 1500
# I am not confused
# Bye

# %%
var =30
print('I think I am wrong')
if var==40:
    print (var, 'is equal to 40')
elif var==20:
    print (var, 'is equal to 39')
elif var<25:
    print (var, 'is less tha 2')
else:
    print ('nothing will happen')
print ('I am right')
# Out:
# I think I am wrong
# nothing will happen
# I am right

# %%
name = 'Besant'
name1= 'technologies'
name2= 'techomologies'

if name != 'Besant' :
    print ('hello Besant -if')

elif name1 == technologies
    print('hello' name)

else:
    print('hello', name2)
print("whatever user has given input")
print("bye")
# Out:
#   Cell In[12], line 8
#     elif name1 == technologies
#                               ^
# SyntaxError: invalid syntax
