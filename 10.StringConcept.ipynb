# %%
updatedNewString = newString[1:]

# %%
'R' + updatedNewString + 's'

# %%
x = 'Besant Technologies'

# %%
print (x)
# Out:
# Besant Technologies

# %%
z = 50

# %%
z+=2 #z  = z + 2 Latest value z =

# %%
print (z)
# Out:
# 52

# %%
x = "Besant Technologies"

# %%
x += "Hebbal Bengaluru"

# %%
print(x)
# Out:
# Besant TechnologiesHebbal BengaluruHebbal Bengaluru

# %%
alphabet = 'q'

# %%
alphabet * 20
# Out:
# 'qqqqqqqqqqqqqqqqqqqq'

# %%
2 + 2
# Out:
# 4

# %%
'2' + '2'
# Out:
# '22'

# %%
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 '2' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
y = 'Besant Technologies Hebbal'

# %%
y.upper
# Out:
# <function str.upper()>

# %%
y.upper()
# Out:
# 'BESANT TECHNOLOGIES HEBBAL'

# %%
var=y.split()

# %%
print(var)
# Out:
# ['Besant', 'Technologies', 'Hebbal']

# %%
newVar = 'We come to Besant Technologies only over the weekends'
#output  'We come to Besant Technologies over weekends'

# %%
newVar.pop (only)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 newVar.pop (only)
#
# NameError: name 'newVar' is not defined

# %%
words = newVar.split()

# %%
newVar
# Out:
# 'We come to Besant Technologies only over the weekends'

# %%
words
# Out:
# ['We',
#  'come',
#  'to',
#  'Besant',
#  'Technologies',
#  'only',
#  'over',
#  'the',
#  'weekends']

# %%
words
