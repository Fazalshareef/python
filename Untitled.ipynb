# %%
dayNo = 10

match dayNo :
    case 1:
        print ("Monday")
    case 2:
        print ("Tuesday")
    case 10:
        print ("Wednesday")
    case 11:
        print ("thirsday")
# Out:
#   Cell In[1], line 3
#     match dayNo :
#           ^
# SyntaxError: invalid syntax
