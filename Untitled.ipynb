# %%
class car():
    def __init__ (self, engine, colour, segemnt):
        self.engine = engine
        self.colour = colour
        self.segment = segment 

    def display (self, analouge, digital):
        self.analouge = analouge
        self.digital = digital


class creata(car):
    def __init__ (self)
    super(). __init__ (self)

    def variant (self,
