# %% [markdown]
# start =1
# end =10
# print ("hi", start)
# while start<=end:
#     print(start)
#     start+=1
#     end-=1
# print("bye", end)

# %%
start =1
end =10
print ("hi", start)
while start<=end:
    print(start)
    start+=1
    end-=1
print("bye", end)
# Out:
# hi 1
# 1
# 2
# 3
# 4
# 5
# bye 5

# %%
x = 10
y = 25

while x <= y:
    print("The current value of x is", x)
    x += 2
else:
    print(x, "is not less than", y)
# Out:
# The current value of x is 10
# The current value of x is 12
# The current value of x is 14
# The current value of x is 16
# The current value of x is 18
# The current value of x is 20
# The current value of x is 22
# The current value of x is 24
# 26 is not less than 25

# %%
x=5
y=15

while (x%2==1) & (x<=8) | (y>=20) & (5>=2) :
    print ("the current value of x is", x)
    x+=2
    print ("this line is after continue")
else:
    print ("x is not less than", y)
print ("I am not confused")
# Out:
# the current value of x is 5
# this line is after continue
# the current value of x is 7
# this line is after continue
# x is not less than 15
# I am not confused

# %%
x=0
y=10
while x<=y:
    x+=1
    if x%2==0:
        if x==2 or x==4:
            print("pass")
        else:
            print(x)
        print(y)
    print ("I am wrong")
print("I will always be printed")
# Out:
# I am wrong
# pass
# 10
# I am wrong
# I am wrong
# pass
# 10
# I am wrong
# I am wrong
# 6
# 10
# I am wrong
# I am wrong
# 8
# 10
# I am wrong
# I am wrong
# 10
# 10
# I am wrong
# I am wrong
# I will always be printed

# %%
#Print all even numbers from 1 to 20.

# %%
for num in range(1,20):
    if num % 2 == 0:
        print (num)
        num = (num+1)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
#Print whether each number between 1 to 10 is even or odd.

# %%
for num in range(1, 10):
    if num % 2 == 0:
        print(num)
        num = (num+1)
# Out:
#   Cell In[5], line 6
#     print (num)
#     ^
# IndentationError: expected an indented block
