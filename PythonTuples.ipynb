# %%
Tuples are very similar to lists. However they have one key difference  -IMMUTABILITY
One element inside a tuple, it cannot be reassigned
Tuples use () paranthesis

# %%
t=(1,2,3)

# %%
list=[1,2,3]

# %%
type(t)
# Out:
# tuple

# %%
type(list)
# Out:
# list

# %%
len(t)
# Out:
# 3

# %%
len(list)
# Out:
# 3

# %%
list[0] = 'one'

# %%
list
# Out:
# ['one', 2, 3]

# %%
t[0] = 'one' #Immuntable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t[0] = 'one' #Immuntable
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=('a','a','b')

# %%
t.count('a')
# Out:
# 2

# %%
t.index('a')
# Out:
# 0

# %%
t=(1,2,2,2,3,3,4,2,5,7)

# %%
t.count(2)
# Out:
# 4

# %%
t.count(9)
# Out:
# 0

# %%
tu = ('a','a','b','c','b')

# %%
tu.index(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tu.index(1)
#
# ValueError: tuple.index(x): x not in tuple
