# %%
class Account():
    def __init__(self, account_number, account_holder_name, balance=0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f'₹{amount} deposited successfully.')
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            print(f"₹{amount} withdrawn successfully.")
        else:
            print("Insufficient balance or invalid amount.")

    def check_balance(self):
        print(f"Available Balance: ₹{self.balance}")

    def calculate_interest(self):
        return 0  


class SavingAccount(Account):
    interest_rate = 0.04  

    def calculate_interest(self):
        interest = self.balance * self.interest_rate
        print(f"Interest earned: ₹{interest}")
        return interest


class CurrentAccount(Account):
    interest_rate = 0.00  
    overdraft_limit = 5000

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance + self.overdraft_limit:
            self.balance -= amount
            print(f"₹{amount} withdrawn successfully ")
        else:
            print("Withdrawal exceeds balance + overdraft limit.")

    def calculate_interest(self):
        print("Current account has no interest.")
        return 0

# %%
if __name__ == "__main__":
    print("----- Saving Account -----")
    sav = SavingAccount(101, "Fazal", 10000)
    sav.deposit(2000)
    sav.withdraw(1000)
    sav.check_balance()
    sav.calculate_interest()

    print("\n----- Current Account -----")
    cur = CurrentAccount(201, "Rahul", 3000)
    cur.deposit(1500)
    cur.withdraw(6000)
    cur.check_balance()
    cur.calculate_interest()
# Out:
# ----- Saving Account -----
# ₹2000 deposited successfully.
# ₹1000 withdrawn successfully.
# Available Balance: ₹6000
# Interest earned: ₹240.0
#
# ----- Current Account -----
# ₹1500 deposited successfully.
# ₹6000 withdrawn successfully (Overdraft applied if needed).
# Available Balance: ₹-1500
# Current account has no interest.
