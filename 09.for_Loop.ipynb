# %%
Loop- 
May objects in Python are "iterable", meaning we can iterate over every element in the object.
    Such as every element in a list or every character in a string
We can use for loop to execute a block of code for every iteration
Consider ITERABLE means going through something

# %%
for Loop

Sytax 
my_iterable = [1,2,3] #list
for item_temp_name in my_iterabble:
    print (item_temp_name)

# %%
myList = [10,20,30,40,50,60,70,80,90]
for templist in myList:
    print (templist**2)
# Out:
# 100
# 400
# 900
# 1600
# 2500
# 3600
# 4900
# 6400
# 8100

# %%
for templist in myList:
    print ("Hello", templist)
# Out:
# Hello 10
# Hello 20
# Hello 30
# Hello 40
# Hello 50
# Hello 60
# Hello 70
# Hello 80
# Hello 90

# %%
for templist in myList:
    print ('* * *')
# Out:
# * * *
# * * *
# * * *
# * * *
# * * *
# * * *
# * * *
# * * *
# * * *

# %%
myList = [1,22,34,41,6,7,9,101,11]
print ("Even Numbers:")
for templist in myList:
    if templist%2==1:
        print(templist)
print ("Odd Numbers:")
for templist in myList:
    if templist%2==0:
        print(templist)
print ("=================")
for templist in myList:
    if templist%4==3:
        print(templist)
# Out:
# Even Numbers:
# 1
# 41
# 7
# 9
# 101
# 11
# Odd Numbers:
# 22
# 34
# 6
# ...
# 7
# 11

# %%
print ("Odd Numbers")
for templist in myList:
    if templist%2==0:
        print('hi')
        break
        print('Bye')
    print (templist)

# %%
print ("Odd Numbers")
for templist in myList:
    if templist%2==0:
        print('hi')
        continue
        print('Bye')
    print (templist)

# %%
for templist in myList:
    if templist%2==0:
        print ("New Number:", templist)
    elif tempList%3==1:
        print ("Number:",templist)
    else:
        print("Hi", templist)

# %%
list_sum = 0
for num in myList: print(list_sum) list_sum+=num print(list_sum)

# %%
list_sum = 10
for num in myList:
    list_sum= num + list_sum + 1
    print (num)
list_sum

# %%
newString = 'Hello World'

for letter in newString:
    print (letter)

# %%
for letter in 'Hello World':
    print(letter)

# %%
#when there is no need of a variable , we would use _ as standard in python

# %%
for _ in 'Hello India':
    print ("Iterate through all characters in as string")

# %%
tup = (4,5,6,6,6,6,6)
for item in tup:
    print (item)

# %%
set = {4,5,6,6,6,6,6}
for item in set:
    print (item)

# %%
TUPLE & PACKING

# %%
myList = [(1,2),(3,4),(5,6),(7,8)]

# %%
len(myList)

# %%
for item in myList:
    print (item)

# %%
for (x,y) in myList:
    print (x+y)

# %%
for (x,y) in myList:
    print (x)
    print (y)

# %%
newList = [(1,'x','KrPuram'),(2,'y','Hebbal'),(3,'z','Silkborad')]

# %%
for CustID,CustName,CustAdd in newList:
    print(CustName)

# %%
di = {'key1':1,'key2': 2, 'key3': 3}

# %%
for item in di:
    print (item)

# %%
for item in di.items():
    print (item)

# %%
for item in di.values():
    print (item)

# %%
for item in di.keys():
    print (item)

# %%
for key,value in di.items():
    print (value + value)
    print (key + key)

# %%
pyramid patteren
