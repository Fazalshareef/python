# %%
Sets are unordered collections of unique elements

Meaning they can only be one representative of the same object

Sets doesnt have paticular order.

# %%
mySet = set()

# %%
type(mySet)
# Out:
# set

# %%
mySet.add(100)

# %%
mySet
# Out:
# {100}

# %%
mySet.add(200)

# %%
mySet
# Out:
# {100, 200}

# %%
mySet.add(40)

# %%
mySet
# Out:
# {40, 100, 200}

# %%
#Testing new set
newSet1 = set()

# %%
newSet1.add(1)

# %%
newSet1.add(0)

# %%
newSet1.add(True)

# %%
newSet1.add(False)

# %%
newSet1.add(3)

# %%
newSet1 #as
# Out:
# {False, True, 3}

# %%
mySet
# Out:
# {40, 100, 200}

# %%
#Convert a list into set

# %%
myList = {4,1,4,2,'a','a','B','b',5,6,4,1,2,1,0}

# %%
set(myList)
# Out:
# {0, 1, 2, 4, 5, 6, 'B', 'a', 'b'}

# %%
newSet = {1,1,2,'Hello',8,9,5,6,6,6,'Hi',200,50,75,90,99,60,10000}

# %%
newSet
# Out:
# {1, 10000, 2, 200, 5, 50, 6, 60, 75, 8, 9, 90, 99, 'Hello', 'Hi'}

# %%
type(newSet)
# Out:
# set

# %%
set1 = set()

# %%
set1.add(1)

# %%
set1.add(True)

# %%
set1.add(0)

# %%
set1.add(2)

# %%
set1.add(False)

# %%
set1
# Out:
# {0, 1, 2}

# %%
set1.add(f

# %%
id={1001,1002,1003,1004,1005,1006}

# %%
id
# Out:
# {1001, 1002, 1003, 1004, 1005, 1006}

# %%
len(id)
# Out:
# 6

# %%
id.add(1007)

# %%
id
# Out:
# {1001, 1002, 1003, 1004, 1005, 1006, 1007}

# %%
id.pop(1006)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 id.pop(1006)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
id.remove(1006)

# %%
id
# Out:
# {1001, 1002, 1003, 1004, 1005, 1007}

# %%
id.pop()
# Out:
# 1001

# %%
id.update({1003})=1009
# Out:
#   Cell In[11], line 1
#     id.update({1003})=1009
#     ^
# SyntaxError: cannot assign to function call

# %%
roll={1001,1002,1003,1004,1005,1006,1007,1008,1009}

# %%
result=id.union(roll)

# %%
id
# Out:
# {1002, 1003, 1004, 1005, 1007}

# %%
result=id.intersection(roll)

# %%
id
# Out:
# {1002, 1003, 1004, 1005, 1007}

# %%
result=roll.intersection(id)

# %%
roll
# Out:
# {1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009}
