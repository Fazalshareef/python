# %%
Inheritance is a way to form new classes using classes that have been defined. The newly formed classes are called derived classes, the classes that 
we derived from are called base (or) super classes. Important benefits of inheritance are code reuse and reduction of complexity of a program.
    The derived classes (descendants) override or extend the functionality of base classes (ancestors)

# %%
class car():

    def add(a, b):
        return a + b

    def __init__(self, model, colour):
        self.model = model
        self.model = colour
my_car = car("Hundai", "black")

# %%
car.add(100, 200)
# Out:
# 300

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(self.model)
#
# NameError: name 'self' is not defined

# %%
class Circle():
    pi = 3.14

    def __init__(self, radius):
        self.radius = radius
        self.area = radius * radius * self.pi   
        

c = Circle(5)

print(c.pi)        
print(c.radius)    
print(c.area)
# Out:
# 3.14
# 5
# 78.5

# %%
class Circle():
    pi = 3.14

    def __init__(self, radius):
        self.radius = radius
        self.area = radius * radius * self.pi   

    def getCircumference(self):
        return self.radius * self.pi * 2

    def getArea(self):
        return self.area

    def setRadius(self, new_radius):
        self.radius = new_radius
        self.area = new_radius * new_radius * self.pi


c = Circle(10)

print(c.getArea())            
print(c.getCircumference())   

c.setRadius(20)               

print(c.getArea())           
print(c.getCircumference())
# Out:
# 314.0
# 62.800000000000004
# 1256.0
# 125.60000000000001

# %%
class Animal():

    species = 'mamal'

    def __init__(self):
        print ('Animal created')

    def whichAnimal(self):
        print ('Animal')

    def eat (self):
        print ('Eating')


class Dog(Animal):

    def __init__(self):
        Animal. __init__(self)
        print('Dog Created')

    def whichAnimal(self):
        print ('Dog')

    def bark (self):
        print ('Woof!')

# %%
frainke = Dog()
# Out:
# Animal created
# Dog Created

# %%
print(frainke.species)
frainke.whichAnimal()
frainke.eat()
frainke.bark()
# Out:
# mamal
# Dog
# Eating
# Woof!

# %%
Polymorphism 

While functions can take in different arguments, methods belong to the objects they act on. Ploymorphism refers to the way in which different 
object classes can share the same method name, and those methods can be called from the same place even though a variety of different objects might be passed in.

# %%
class Dog():
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + 'says Woof!'

class Cat():
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + 'says Meow!'

obj1 = Dog('Johnny')
obj2 = Cat('Tom')

print(obj1.speak())
print(obj2.speak())
# Out:
# Johnnysays Woof!
# Tomsays Meow!

# %%
# demonstrate polymorphism using a for loop

for pet in [obj1, obj2]:
    print(pet.speak())
# Out:
# Johnnysays Woof!
# Tomsays Meow!

# %%
# demonstrate polymorphism using functions

def pet_speak(pet):
    print (pet.speak())

pet_speak(obj1)    
pet_speak(obj1)
# Out:
# Johnnysays Woof!
# Johnnysays Woof!

# %%
Classes in Python can implement certain operations with special method names. These methods are not actually called directly but by
Python specific lanuguage syntax.

# %%
class Book():
    def __init__(self, title, author, pages):
        print("A book is created")
        self.title = title
        self.author = author
        self.pages = pages

    def __str__ (self):
        return "Title: %s, author: %s, pages: %s" %(self.title, self.author, self.pages)


    def __len__ (self):
        return self.pages

    def __del__ (self):
        print ("A book has been deleted")

pythonBook = Book("Pyhton is amazing" , "Besant Technologies", 160)
# Out:
# A book is created

# %%
pythonBook

# %%
print(pythonBook)
# Out:
# Title: Pyhton is amazing, author: Besant Technologies, pages: 160

# %%
print(len(pythonBook))
# Out:
# 160

# %%
del pythonBook
# Out:
# A book has been deleted
