# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc

# %%
import pyodbc
print("pyodbc working:", pyodbc.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pyodbc
#       2 print("pyodbc working:", pyodbc.__version__)
#
# ImportError: dlopen(/Users/fazalshareef/Downloads/python/lib/python3.9/site-packages/pyodbc.cpython-39-darwin.so, 0x0002): Library not loaded: /opt/homebrew/opt/unixodbc/lib/libodbc.2.dylib
#   Referenced from: <972B4929-ED5A-3A5E-A250-DE176888FE6B> /Users/fazalshareef/Downloads/python/lib/python3.9/site-packages/pyodbc.cpython-39-darwin.so
#   Reason: tried: '/opt/homebrew/opt/unixodbc/lib/libodbc.2.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/unixodbc/lib/libodbc.2.dylib' (no such file), '/opt/homebrew/opt/unixodbc/lib/libodbc.2.dylib' (no such file)

# %%
#create a connection string object
connection_string = pyobdc.connect("DRIVER={SQL server};Server=Server_name\\SQLEXPRESS;Database=CustomerDetails1;TrustedConnection=yes")
# Out:
#   Cell In[3], line 1
#     create a connection string object
#            ^
# SyntaxError: invalid syntax

# %%
cursor = conection_string.cursor() # Create a cursor object. The cursor object is used to execute sql queries  and retrive data

# %%
#Execute a SQL query
cursor.execute('SELECT * FROM Table_name')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Execute a SQL query
# ----> 2 cursor.execute('SELECT * FROM Table_name')
#
# NameError: name 'cursor' is not defined

# %%
#Retrive the data from the database
rows = cursor.fecthall()

# %%
#Display the row in the list
rows

# %%
for row in rows:
    print (row)

# %%
for id,name,address in rows:
    print(name+"@company_email.com")

# %%
for id,name,address in rows:
    if id == 102:
        print(f"Second row only {id}")

# %%
cursor.close()
connection_string.close()
